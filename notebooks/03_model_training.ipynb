# %% [markdown]
# # Model training
#
# This notebook uses the cleaned dataset to train candidate default-risk models and stores the best-performing model for future inference.

# %%
from pathlib import Path

import pandas as pd

from src.model.train import main

main()
