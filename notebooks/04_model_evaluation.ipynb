# %% [markdown]
# # Model evaluation
#
# This notebook evaluates the selected trained model on the saved cleaned dataset and writes metrics and figures to the reports directory.

# %%
from src.model.evaluate import evaluate_saved_model

metrics = evaluate_saved_model()
print(metrics)
