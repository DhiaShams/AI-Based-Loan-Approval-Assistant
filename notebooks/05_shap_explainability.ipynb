# %% [markdown]
# # SHAP explainability
#
# This notebook loads a trained model and explains the feature contributions for a sample applicant record.

# %%
from src.explainability.shap_explainer import explain_applicant

sample = {
    "loan_amnt": 25000,
    "annual_inc": 70000,
    "dti": 25,
    "fico_range_low": 690,
    "revol_util": 45,
    "term": 36,
    "int_rate": 10,
    "emp_length": 5,
    "home_ownership": "MORTGAGE",
    "verification_status": "Verified",
    "purpose": "debt_consolidation",
    "grade": "B",
    "sub_grade": "B2",
    "issue_d": "2020-01-01",
    "earliest_cr_line": "2013-01-01",
}

result = explain_applicant(sample)
print(result["top_increasing_risk"])
print(result["top_reducing_risk"])
